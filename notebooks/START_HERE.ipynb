# %% [markdown]
# # Introduction to connecting and Querying the Augur DB

# %% [markdown]
# If you made to this point, welcome! :) This short tutorial will show how to connect to the database and how to do a simple query. If you need the config file please email cdolfi@redhat.com
#
# For Project Sandiego's data, we will be using a personal instance of Augur. Augur is a software suite for collecting and measuring structured data about free and open-source software (FOSS) communities.
#
# Augur gather's trace data for a group of repositories, normalize it into the data model, and provide a variety of metrics about said data. The structure of the data model enables us to synthesize data across various platforms to provide meaningful context for meaningful questions about the way these communities evolve.
#
# All the notebooks in this folder are based on https://github.com/chaoss/augur-community-reports templates.

# %% [markdown]
# ## Connect to your database

# %% [markdown]
# Until the Operate First enviroment can connect to the DB, use config file to access. Do not push config file to Github repo

# %%
import psycopg2
import pandas as pd 
import sqlalchemy as salc
import json
import os

with open("../comm_cage.json") as config_file:
    config = json.load(config_file)

# %%
database_connection_string = 'postgresql+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = salc.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %% [markdown]
# ### Retrieve Available Respositories

# %%
aval_repos = pd.DataFrame()
repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT a.rg_name,
                a.repo_group_id,
                b.repo_name,
                b.repo_id,
                b.forked_from,
                b.repo_archived,
                b.repo_git
            FROM
                repo_groups a,
                repo b
            WHERE
                a.repo_group_id = b.repo_group_id
            ORDER BY
                rg_name,
                repo_name;
    """)
aval_repos = pd.read_sql(repo_query, con=engine)
display(aval_repos)
aval_repos.dtypes
# Out:
#         rg_name  repo_group_id                       repo_name  repo_id  \
# 0        3scale          25556                          3scale    33134
# 1        3scale          25556  3scale-amp-openshift-templates    33126
# 2        3scale          25556               3scale-api-python    33130
# 3        3scale          25556                 3scale-api-ruby    33158
# 4        3scale          25556                3scale-go-client    33169
# ...         ...            ...                             ...      ...
# 10956  zerodayz          25482              sosreport-operator    30872
# 10957  zerodayz          25482                           talos    30863
# 10958  zerodayz          25482                           tests    30838
# 10959  zerodayz          25482                             web    30839
# 10960  zerodayz          25482                        zerodayz    30816
#
#                            forked_from  repo_archived  \
# 0                 Parent not available            0.0
# 1                 Parent not available            0.0
# 2          3scale-qe/3scale-api-python            0.0
# 3                 Parent not available            0.0
# 4                 Parent not available            0.0
# ...                                ...            ...
# 10956  andreaskaris/sosreport-operator            0.0
# 10957                 siderolabs/talos            0.0
# 10958            kata-containers/tests            0.0
# 10959                openshifttips/web            0.0
# 10960             Parent not available            0.0
#
#                                                 repo_git
# 0             https://github.com/3scale/3scale.github.io
# 1      https://github.com/3scale/3scale-amp-openshift...
# 2            https://github.com/3scale/3scale-api-python
# 3              https://github.com/3scale/3scale-api-ruby
# 4             https://github.com/3scale/3scale-go-client
# ...                                                  ...
# 10956     https://github.com/zerodayz/sosreport-operator
# 10957                  https://github.com/zerodayz/talos
# 10958                  https://github.com/zerodayz/tests
# 10959                    https://github.com/zerodayz/web
# 10960     https://github.com/zerodayz/zerodayz.gitlab.io
#
# [10961 rows x 7 columns]
# rg_name           object
# repo_group_id      int64
# repo_name         object
# repo_id            int64
# forked_from       object
# repo_archived    float64
# repo_git          object
# dtype: object

# %% [markdown]
# ### Create a Simpler List for quickly Identifying repo_group_id's and repo_id's for other queries

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT b.repo_id,
                a.repo_group_id,
                b.repo_name,
                a.rg_name,
                b.repo_git
            FROM
                repo_groups a,
                repo b 
            WHERE
                a.repo_group_id = b.repo_group_id 
            ORDER BY
                rg_name,
                repo_name;   

    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist
# Out:
#        repo_id  repo_group_id                       repo_name   rg_name  \
# 0        33134          25556                          3scale    3scale
# 1        33126          25556  3scale-amp-openshift-templates    3scale
# 2        33130          25556               3scale-api-python    3scale
# 3        33158          25556                 3scale-api-ruby    3scale
# 4        33169          25556                3scale-go-client    3scale
# ...        ...            ...                             ...       ...
# 10956    30872          25482              sosreport-operator  zerodayz
# 10957    30863          25482                           talos  zerodayz
# 10958    30838          25482                           tests  zerodayz
# 10959    30839          25482                             web  zerodayz
# 10960    30816          25482                        zerodayz  zerodayz
#
#                                                 repo_git
# 0             https://github.com/3scale/3scale.github.io
# 1      https://github.com/3scale/3scale-amp-openshift...
# 2            https://github.com/3scale/3scale-api-python
# 3              https://github.com/3scale/3scale-api-ruby
# 4             https://github.com/3scale/3scale-go-client
# ...                                                  ...
# 10956     https://github.com/zerodayz/sosreport-operator
# 10957                  https://github.com/zerodayz/talos
# 10958                  https://github.com/zerodayz/tests
# 10959                    https://github.com/zerodayz/web
# 10960     https://github.com/zerodayz/zerodayz.gitlab.io
#
# [10961 rows x 5 columns]

# %%
repolist[50:70]
# Out:
#     repo_id  repo_group_id                         repo_name rg_name  \
# 50    33174          25556           lua-resty-limit-traffic  3scale
# 51    33144          25556                     lua-resty-url  3scale
# 52    33110          25556                         lua-rover  3scale
# 53    33172          25556                message_bus_client  3scale
# 54    33184          25556               nginx-upstream-fair  3scale
# 55    33179          25556                         node-sass  3scale
# 56    33154          25556  openid-connect-api-gateway-rhsso  3scale
# 57    33109          25556                   oracle-database  3scale
# 58    33143          25556                      Penlight-ffi  3scale
# 59    33151          25556                            pisoni  3scale
# 60    33121          25556                             porta  3scale
# 61    33162          25556                             prawn  3scale
# 62    33171          25556               proxy-wasm-rust-sdk  3scale
# 63    33164          25556                              puma  3scale
# 64    33170          25556                  rack-x_served_by  3scale
# 65    33111          25556                          redis-rb  3scale
# 66    33133          25556                            resque  3scale
# 67    33186          25556                       resque-pool  3scale
# 68    33122          25556                roda-parse-request  3scale
# 69    33106          25556               rspec-html-matchers  3scale
#
#                                              repo_git
# 50  https://github.com/3scale/lua-resty-limit-traffic
# 51            https://github.com/3scale/lua-resty-url
# 52                https://github.com/3scale/lua-rover
# 53       https://github.com/3scale/message_bus_client
# 54      https://github.com/3scale/nginx-upstream-fair
# 55                https://github.com/3scale/node-sass
# 56  https://github.com/3scale/openid-connect-api-g...
# 57          https://github.com/3scale/oracle-database
# 58             https://github.com/3scale/Penlight-ffi
# 59                   https://github.com/3scale/pisoni
# 60                    https://github.com/3scale/porta
# 61                    https://github.com/3scale/prawn
# 62      https://github.com/3scale/proxy-wasm-rust-sdk
# 63                     https://github.com/3scale/puma
# 64         https://github.com/3scale/rack-x_served_by
# 65                 https://github.com/3scale/redis-rb
# 66                   https://github.com/3scale/resque
# 67              https://github.com/3scale/resque-pool
# 68       https://github.com/3scale/roda-parse-request
# 69      https://github.com/3scale/rspec-html-matchers

# %% [markdown]
# ### Create a list of all of the tables with the total number of data entries

# %%
data_entries = pd.DataFrame()

repo_query = salc.sql.text(f"""
                ANALYZE;
                SELECT schemaname,relname,n_live_tup 
                  FROM pg_stat_user_tables 
                  ORDER BY n_live_tup DESC;

    """)

data_entries = pd.read_sql(repo_query, con=engine)

data_entries
# Out:
#      schemaname               relname  n_live_tup
# 0    augur_data                issues     4227162
# 1    augur_data     pull_request_meta     2629237
# 2    augur_data   pull_request_labels     1875821
# 3    augur_data   pull_request_events     1782713
# 4    augur_data    pull_request_files     1151045
# ..          ...                   ...         ...
# 435  augur_data  merge_data_0_1103194           0
# 436  augur_data  merge_data_0_4087352           0
# 437  augur_data  merge_data_0_3537777           0
# 438  augur_data  contributors_aliases           0
# 439  augur_data    merge_data_0_40603           0
#
# [440 rows x 3 columns]

# %% [markdown]
# Congrats you have done your first queries! There will be a few more simple examples below on how to pull an entire table. If you would like to explore on your own, the schema.png on the home sandiego directory will be greatly helpful in your explorations! Happy querying :)

# %% [markdown]
# ### Data from the messages
#
# This data is the collection of all comments from any issue, PR, commit, etc opened. This example shows another side of the database and the types of data we can pull from it.

# %%
mes_data = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM message
    """)

mes_data = pd.read_sql(repo_query, con=engine)

mes_data
# Out:
#             msg_id rgls_id  platform_msg_id  \
# 0            25430    None        826722981
# 1            25431    None        826812453
# 2            25432    None        826815197
# 3            25433    None        826817026
# 4            25434    None        826822231
# ...            ...     ...              ...
# 10009658  14997064    None        885743169
# 10009659  14997065    None        885933776
# 10009660  14997069    None        786170310
# 10009661  14997070    None        786201847
# 10009662  14997071    None        792769758
#
#                               platform_node_id  repo_id  cntrb_id  \
# 0         MDEyOklzc3VlQ29tbWVudDgyNjcyMjk4MQ==      NaN     25440
# 1         MDEyOklzc3VlQ29tbWVudDgyNjgxMjQ1Mw==      NaN     25449
# 2         MDEyOklzc3VlQ29tbWVudDgyNjgxNTE5Nw==      NaN     25438
# 3         MDEyOklzc3VlQ29tbWVudDgyNjgxNzAyNg==      NaN     25440
# 4         MDEyOklzc3VlQ29tbWVudDgyNjgyMjIzMQ==      NaN     25449
# ...                                        ...      ...       ...
# 10009658                 PRRC_kwDOAynl5s40y15B  25729.0   2257510
# 10009659                 PRRC_kwDOAynl5s40zkbQ  25729.0   2257510
# 10009660                 PRRC_kwDOAynl5s4u3AHG  25729.0   2474932
# 10009661                 PRRC_kwDOAynl5s4u3Hz3  25729.0   2474932
# 10009662                 PRRC_kwDOAynl5s4vQLTe  25729.0   2474932
#
#                                                    msg_text  \
# 0         I've enabled actions for this repo. LMK if it ...
# 1         [APPROVALNOTIFIER] This PR is **NOT APPROVED**...
# 2                Actions seems to be working now. Thanks 👍
# 3                                          /cc @oindrillac
# 4         [APPROVALNOTIFIER] This PR is **NOT APPROVED**...
# ...                                                     ...
# 10009658  Works for me locally but may not be supported ...
# 10009659  Not sure what happened with the windows build ...
# 10009660  I think it's negative for west, since EST is w...
# 10009661  Is EST being east of UTC a time zone conventio...
# 10009662    Is there an initial value that you had in mind?
#
#                msg_timestamp msg_sender_email msg_header  pltfrm_id  \
# 0        2021-04-26 10:35:38             None       None      25150
# 1        2021-04-26 12:55:35             None       None      25150
# 2        2021-04-26 12:59:50             None       None      25150
# 3        2021-04-26 13:02:13             None       None      25150
# 4        2021-04-26 13:09:08             None       None      25150
# ...                      ...              ...        ...        ...
# 10009658 2022-05-31 14:54:06             None       None      25150
# 10009659 2022-05-31 17:48:58             None       None      25150
# 10009660 2022-01-17 16:51:30             None       None      25150
# 10009661 2022-01-17 17:28:48             None       None      25150
# 10009662 2022-01-26 15:40:07             None       None      25150
#
#                          tool_source tool_version data_source  \
# 0                  GitHub API Worker        1.0.0  GitHub API
# 1                  GitHub API Worker        1.0.0  GitHub API
# 2                  GitHub API Worker        1.0.0  GitHub API
# 3                  GitHub API Worker        1.0.0  GitHub API
# 4                  GitHub API Worker        1.0.0  GitHub API
# ...                              ...          ...         ...
# 10009658  GitHub Pull Request Worker        1.2.0  GitHub API
# 10009659  GitHub Pull Request Worker        1.2.0  GitHub API
# 10009660  GitHub Pull Request Worker        1.2.0  GitHub API
# 10009661  GitHub Pull Request Worker        1.2.0  GitHub API
# 10009662  GitHub Pull Request Worker        1.2.0  GitHub API
#
#          data_collection_date
# 0         2021-10-21 13:41:55
# 1         2021-10-21 13:41:55
# 2         2021-10-21 13:41:55
# 3         2021-10-21 13:41:55
# 4         2021-10-21 13:41:55
# ...                       ...
# 10009658  2022-08-22 11:23:01
# 10009659  2022-08-22 11:23:01
# 10009660  2022-08-22 11:23:01
# 10009661  2022-08-22 11:23:01
# 10009662  2022-08-22 11:23:01
#
# [10009663 rows x 15 columns]

# %% [markdown]
# ### Contributor affiliation data
#
#
# This data tells us what is the company affiliation of many open source contributors. This can help tell us which companies are involved in a certian open source project.

# %%
con_aff = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM contributor_affiliations
    """)

con_aff = pd.read_sql(repo_query, con=engine)

con_aff
# Out:
#      ca_id            ca_domain ca_start_date        ca_last_used  \
# 0        1          samsung.com    1970-01-01 2018-08-01 18:37:54
# 1        2  linuxfoundation.org    1970-01-01 2018-08-01 18:37:54
# 2        3              ibm.com    1970-01-01 2018-08-01 18:37:54
# 3        8          walmart.com    1970-01-01 2018-09-01 06:00:00
# 4        9       exxonmobil.com    1970-01-01 2018-09-01 06:00:00
# ..     ...                  ...           ...                 ...
# 515    516          twitter.com    1970-01-01 2018-09-01 06:00:00
# 516    517            adobe.com    1970-01-01 2018-09-01 06:00:00
# 517    519              acm.org    1970-01-01 2018-09-12 02:01:59
# 518    520     outdoors@acm.org    1970-01-01 2018-09-12 02:32:53
# 519    521          freebsd.org    1970-01-01 2018-09-13 21:15:22
#
#              ca_affiliation  ca_active tool_source tool_version data_source  \
# 0                   Samsung          1        load          1.0        load
# 1          Linux Foundation          1        load          1.0        load
# 2                       IBM          1        load          1.0        load
# 3                   Walmart          1        load          1.0        load
# 4               Exxon Mobil          1        load          1.0        load
# ..                      ...        ...         ...          ...         ...
# 515                 Twitter          1        load          1.0        load
# 516                   Adobe          1        load          1.0        load
# 517                     ACM          1        load          1.0        load
# 518  University of Missouri          1        load          1.0        load
# 519                Free BSD          1        load          1.0        load
#
#     data_collection_date
# 0             1970-01-01
# 1             1970-01-01
# 2             1970-01-01
# 3             1970-01-01
# 4             1970-01-01
# ..                   ...
# 515           1970-01-01
# 516           1970-01-01
# 517           1970-01-01
# 518           2013-07-15
# 519           1970-01-01
#
# [520 rows x 10 columns]
